# %% [markdown]
# #Installation - Google Colab
#
#
# ```
# import spacy.cli
# spacy.cli.download("en_core_web_sm")
# ```

# %%
import spacy.cli
spacy.cli.download('en_core_web_sm')
# Out:
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
type(nlp)
# Out:
# spacy.lang.en.English

# %% [markdown]
# #Pipeline
# When you call nlp on a text, spaCy first tokenizes the text to produce a Doc object. The Doc is then processed in several different steps – this is also referred to as the processing pipeline. The pipeline used by the default models consists of a tagger, a parser and an entity recognizer. Each pipeline component returns the processed Doc, which is then passed on to the next component.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
nlp.pipeline
# Out:
# [('tagger', <spacy.pipeline.pipes.Tagger at 0x7f94019594a8>),
#  ('parser', <spacy.pipeline.pipes.DependencyParser at 0x7f9401867768>),
#  ('ner', <spacy.pipeline.pipes.EntityRecognizer at 0x7f94018677c8>)]

# %% [markdown]
# #Tokenizer
# The first step in processing text is to split up all the component parts (words & punctuation) into "tokens".

# %%
doc = nlp('Apple is looking at buying U.K. startup for $6 millions.')

for token in doc:
  print(token.text , token.pos_ , token.dep_)
# Out:
# Apple PROPN nsubj
# is AUX aux
# looking VERB ROOT
# at ADP prep
# buying VERB pcomp
# U.K. PROPN compound
# startup NOUN dobj
# for ADP prep
# $ SYM quantmod
# 6 NUM nummod
# millions NOUN pobj
# . PUNCT punct

# %%
spacy.explain('nsubj')
# Out:
# 'nominal subject'

# %%
spacy.explain('dobj')
# Out:
# 'direct object'

# %%
doc
# Out:
# Apple is looking at buying U.K. startup for $6 millions.

# %%
type(doc)
# Out:
# spacy.tokens.doc.Doc

# %% [markdown]
# #Parts of Speech Tagging

# %%
doc[0].pos_
# Out:
# 'PROPN'

# %%
spacy.explain('PROPN')
# Out:
# 'proper noun'

# %%
doc[4].pos_
# Out:
# 'VERB'

# %% [markdown]
# # Dependencies

# %%
doc[0].dep_
# Out:
# 'nsubj'

# %%
doc[0]
# Out:
# Apple

# %%
doc[2]
# Out:
# looking

# %%
doc[2].dep_
# Out:
# 'ROOT'

# %% [markdown]
# #Some Attributes
#
#
# 1.   Text
# 2.   Lemmatization
# 3.   Is Alpha
# 4.   Is Stop word

# %%
doc
# Out:
# Apple is looking at buying U.K. startup for $6 millions.

# %%
doc[1].text
# Out:
# 'is'

# %%
doc[4].lemma_
# Out:
# 'buy'

# %%
doc[-3].is_alpha
# Out:
# False

# %%
doc[-3]
# Out:
# 6

# %%
doc[0].is_stop
# Out:
# False

# %%
#Thank you!!

# %% [markdown]
# **Like, share, and subscribe to the channel NERCHUKO**
